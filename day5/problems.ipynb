# %%
salary = float(input("Enter salary: "))

if salary < 0:
    print("Invalid salary")
elif salary >= 50000:
    print("Salary after bonus:", salary + 3000)
elif salary >= 40000:
    print("Salary after bonus:", salary + 2000)
elif salary >= 30000:
    print("Salary after bonus:", salary + 1000)
else:
    print("Salary is fixed:", salary)
# Out:
# Enter salary:  34
# Salary is fixed: 34.0

# %%
ch=input("enter the day:")
if ch in "sunday,saturday" :
    print("weekend")
else:
    print("weekdays")
# Out:
# enter the day: friday
# weekdays

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
operation = input("Enter operation (+, -, *, /): ")

# Perform the requested operation
if operation == '+':
    result = num1 + num2
elif operation == '-':
    result = num1 - num2
elif operation == '*':
    result = num1 * num2
elif operation == '/':
    if num2 != 0:
        result = num1 / num2
    else:
        result = "Error! Division by zero."
else:
    result = "Invalid operation."

print("Result:", result)
# Out:
# Enter first number:  34
# Enter second number:  45
# Enter operation (+, -, *, /):  /
# Result: 0.7555555555555555

# %%
a=int(input("enter a number"))
b=int(input("enter a  number"))
c=int(input("enter a number"))
if a>b:
    if a>c:
        print("a is bigger")
    else:
        print("c is bigger")
elif b>c:
    print("b is bigger")
else:
    print("c is bigger")
# Out:
# enter a number 34
# enter a  number 12
# enter a number 10
# a is bigger

# %%
a=int(input("enter a angle value:"))
b=int(input("enter a angle value:"))
c=int(input("enter a angle value:"))
if a>0 and b>0 and c>0:
      if a+b+c==180:
         print("valid triangle")
      else:
          print("invalid")
else:
    print("Angles must be greater than 0")
# Out:
# enter a angle value: 60
# enter a angle value: 60
# enter a angle value: 60
# valid triangle

# %%
a=int(input("enter value"))
b=int(input("enter a value"))
c=int(input("enter a value"))
if a==b and b==c:
    if a==c:
        print("it is a equaliteral")
    else:
        print("not ")
elif  a==b and b==c or a==c:
    print("it is isoscles")
else:
    print("scalessee")
# Out:
# enter value 45
# enter a value 45
# enter a value 60
# scalessee

# %%
num1=int(input("enter a number:"))
if num1%2==0:
    if num1%3==0:
        print("both are divisible by 2 and 3")
    else:
        print("not")
else:
    print("not")
# Out:
# enter a number: 30
# both are divisible by 2 and 3

# %%
user="admin0123"
password=1234
a=input("enter user")
b=int(input("enter password"))
if a==user:
    if b==password:
        print("YOU LOGGEDIN")
    else:
         print("CAN'T LOGGED IN")
else:
    print("CAN'T LOGGED IN")
# Out:
# enter user admin0123
# enter password 1234
# YOU LOGGEDIN

# %%
balance=500
amount=float(input("enter the amount:"))
if amount>0:
    if amount<=500:
        balance=balance-amount
        print("your transcation is successfull")
        print("the remaining is, ",balance)
    else:
         print("insufficient balance")
else:
    print("no balance")
# Out:
# enter the amount: 400
# your transcation is successfull
# the remaining is,  100.0

# %%
year=int(input("enter a year"))
if year%4==0:
    if year%100==0:
        if year%400==0:
            print("leap year")
        else:
            print("not a leap year")
    else:
        print("leap year")
else:
    print("not a leap year")
# Out:
# enter a year 2012
# leap year

# %%
num=int(input("enter a number"))
if 0 <= num <=10:
    print("the ranges is between 1 to 10")
elif 11 <= num <=20:
    print("the ranges is between 11 to 20")
elif 21 <= num <=30:
    print("the ranges is between 21 and 30")
elif 31 <= num <=40:
    print("the ranges is between 31 to 40")
else:
    print("the number is invalid")
# Out:
# enter a number 22
# the ranges is between 21 and 30

# %%
import math 
a = int(input("Enter first side: "))
b = int(input("Enter second side: "))
c = int(input("Enter third side: "))

if (a*a + b*b == c*c) or (a*a + c*c == b*b) or (b*b + c*c == a*a):
    print("Right Triangle")
else:
    print("Not a Right Triangle")
# Out:
# Enter first side:  3
# Enter second side:  4
# Enter third side:  5
# Right Triangle

# %%
units = int(input("Enter electricity units: "))

if units >= 0:
    if units <= 100:
        bill = units * 2
    else:
        if units <= 200:
            bill = units * 3
        else:
            bill = units * 5

    print("Electricity Bill = ₹", bill)
else:
    print("Invalid Units")
# Out:
# Enter electricity units:  500
# Electricity Bill = ₹ 2500
