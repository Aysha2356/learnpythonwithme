# %% [markdown]
# THIS CONTAINS FULL OF CONDITIONAL STATEMENT CODE

# %%
num1=int(input("enter a number"))
if num1>=0:
    print("positive")
else:
    print("negative")
# Out:
# enter a number 45
# positive

# %%
num1=int(input("enter a number"))
if num1%2==0:
    print("even")
else:
    print("odd")
# Out:
# enter a number 34
# even

# %%
num1=int(input("enter a number"))
num2=int(input("enter a number"))
if num1>=num2:
    print("largest is",num1)
else:
    print("largest is",num2)
# Out:
# enter a number 38
# enter a number 25
# largest is 38

# %%
num1=int(input("enter a number"))
num2=int(input("enter a number"))
if num1<=num2:
    print("num1 is smaller")
else:
    print("num2 is smaller")
# Out:
# enter a number 56
# enter a number 12
# num2 is smaller

# %%
num1=int(input("enter a number"))
if num1%3==0 and num1%7==0:
    print("the number is divisible by 3 and 7")
else:
    print("not divisible")
# Out:
# enter a number 21
# the number is divisible by 3 and 7

# %%
age=int(input("enter your age"))
if age>=18:
    print("you can vote")
else:
    print("not eligibile")
# Out:
# enter your age 34
# you can vote

# %%
num1=int(input("enter a number"))
if num1<0:
    print(num1*-1)
else:
    print(num1)
# Out:
# enter a number -89
# 89

# %%
ch=input("enter a char")
if ch in "AEIOU":
    ch=ch.upper()
    print("vowel")
else:
    print("consonnat")
# Out:
# enter a char Q
# consonnat

# %%
num1=int(input("enter number 1:"))
num2=int(input("enter number 2:"))
num3=int(input("enter number 3:"))
if num1>num2 and num2>num3:
    print("the biggest",num1)
elif num2>num3 and num2>num1:
    print("the biggest is ",num2)
else:
    print("the biggest is ",num3)
# Out:
# enter number 1: 45
# enter number 2: 67
# enter number 3: 23
# the biggest is  67

# %%
a=int(input("enter marks:"))
if a>=90:
    print("the grade is A")
elif a<=80 and a>=70:
    print("grade is B")
else:
    print("RA")
# Out:
# enter marks: 70
# grade is B

# %%
num1=int(input("enter a number"))
if num1>0:
    print("positive")
elif num1<0:
    print("negative")
else:
    print("zero")
# Out:
# enter a number -2
# negative

# %%
year = int(input("Enter year: "))

if year % 400 == 0:
    print("Leap Year")
elif year % 100 == 0:
    print("Not a Leap Year")
elif year % 4 == 0:
    print("Leap Year")
else:
    print("Not a Leap Year")
# Out:
# Enter year:  2012
# Leap Year

# %%
age =int(input("enter a age:"))
if 0 <= age <=15:
    print("child")
elif 16 <= age <=30:
    print("adult")
elif 31<= age <=60:
    print("old age")
else :
    print("yup !  you died")
# Out:
# enter a age: 24
# adult

# %%
cp=float(input("enter a amount"))
sp=float(input("enter amount"))
if cp<sp:
    print("profit",sp-cp)
elif cp>sp:
    print("loss",cp-sp)
elif cp==sp:
    print("equal")
else:
    print("invalid amount")
# Out:
# enter a amount 450
# enter amount 500
# profit 50.0

# %%
units=float(input("enter units:"))
if 0<= units <=100:
    print("the amount is:",units*1.5)
elif 101 <=units <=200:
    print("the amount is :",units*2.0)
else:
    print("the amount is :",units*3.0)
# Out:
# enter units: 200
# the amount is : 400.0
